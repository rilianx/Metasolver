# %%
import os

# %%
def read_txt(path):
    txt = open(path)
    data = txt.read().split('\n')
    txt.close()
    return data

# %%
def export_txt(data, random_state):
    output = ''
    for i in data:
        if i != '':
            output += str(i) + '\n'
    output = output.replace('.', ',')
    print(output)
    file = open('test_metrics/metrics_random_state' + str(random_state) + '.txt','w')
    file.write(output)
    file.close()
    print('Metrics save in:', os.getcwd())

# %%
DATADIR = "test_metrics/"

for random_state in range(0, 6):
    txt_sample_list = []
    list_txt = [txt for txt in os.listdir(DATADIR) if ("to" in txt and txt.endswith('random_state' + str(random_state) + '.txt') and '~$' not in name_txt)]
    for name_txt in list_txt:
        data = read_txt(DATADIR + name_txt)
        header = data[0]
        data = data[1:len(data)]
        for line in data:
            if line != '':
                txt_sample_list.append(line)
    txt_sample_list.insert(0, header)
    export_txt(txt_sample_list, random_state)
    del txt_sample_list
# Out:
# hidden_layer_0	hidden_layer_1	loss_mae	mse	root_mean_squared_error	mae
# 10	76	0,013212365361691921	0,0002543020395879741	0,013212365361691921	0,013212365361691921
# 10	77	0,018044954370568123	0,0004108660116273882	0,018044954370568123	0,018044954370568123
# 10	78	0,009622209991170382	0,00018889554272447548	0,009622209991170382	0,009622209991170382
# 10	79	0,008794128832684605	0,0001743038873163318	0,008794128832684605	0,008794128832684605
# 10	80	0,008041050799465327	0,00017219259117080423	0,008041050799465327	0,008041050799465327
# 10	81	0,010762291565823708	0,00020453615481602456	0,010762291565823708	0,010762291565823708
# 10	82	0,007823166051301051	0,00016169947135929872	0,007823166051301051	0,007823166051301051
# 10	83	0,007904898139211799	0,0001726843084466098	0,007904898139211799	0,007904898139211799
# 10	84	0,010507887553348104	0,00024092575229106526	0,010507887553348104	0,010507887553348104
# ...
